# %%
import torch
import pandas as pd
# Out:
# Failed to start the Kernel 'Python 3 (ipykernel) (Untitled-1.ipynb)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:e423e301-bbff-429e-8d6d-84d4436a5d9f

# %%
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: False

# %%
import os

# Clone your repository
# !git clone https://github.com/james-burdon/MDM3-dynamic-therapeutics/tree/main

# Change to the repository directory
os.chdir('/content/MDM3-dynamic-therapeutics')

# Now read the file
file_path = 'physiological_with_activity_labels.csv'
print(f"File exists: {os.path.exists(file_path)}")
phys = pd.read_csv(file_path)
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
